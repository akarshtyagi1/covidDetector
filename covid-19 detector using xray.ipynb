# %%
import pandas as pd
import shutil
import os

# %%
# create the data for positive sample(Github)
FILE_PATH = "git-chestxray/metadata.csv"
IMAGE_PATH = "git-chestxray/images"

# %%
df = pd.read_csv(FILE_PATH)
print(df.shape)
# Out:
# (950, 30)

# %%
df.head()
# Out:
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1         2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2         2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 3         2     6.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 4         4     0.0   F  52.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
# 1        Y         N                  N        N  ...  January 25, 2020
# 2        Y         N                  N        N  ...  January 27, 2020
# 3        Y         N                  N        N  ...  January 28, 2020
# 4      NaN         N                  N        N  ...  January 25, 2020
#
#                                             location  folder  \
# ...

# %%
TARGET_DIR = "dataset/COVID"

if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Covid folder created")
# Out:
# Covid folder created

# %%
cnt=0

for(i,row) in df.iterrows():
    if row["finding"]=="Pneumonia/Viral/COVID-19" and row["view"]=="PA":
        filename = row["filename"]
        image_path = os.path.join(IMAGE_PATH,filename)
        image_copypath= os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copypath)
        print("Moving Image",cnt)
        cnt+=1
        
print(cnt)
# Out:
# Moving Image 0
# Moving Image 1
# Moving Image 2
# Moving Image 3
# Moving Image 4
# Moving Image 5
# Moving Image 6
# Moving Image 7
# Moving Image 8
# Moving Image 9
# Moving Image 10
# Moving Image 11
# Moving Image 12
# Moving Image 13
# Moving Image 14
# Moving Image 15
# Moving Image 16
# Moving Image 17
# Moving Image 18
# Moving Image 19
# Moving Image 20
# Moving Image 21
# Moving Image 22
# Moving Image 23
# Moving Image 24
# Moving Image 25
# Moving Image 26
# Moving Image 27
# Moving Image 28
# Moving Image 29
# Moving Image 30
# Moving Image 31
# Moving Image 32
# Moving Image 33
# Moving Image 34
# Moving Image 35
# Moving Image 36
# Moving Image 37
# Moving Image 38
# Moving Image 39
# Moving Image 40
# Moving Image 41
# Moving Image 42
# Moving Image 43
# Moving Image 44
# Moving Image 45
# Moving Image 46
# Moving Image 47
# Moving Image 48
# Moving Image 49
# Moving Image 50
# Moving Image 51
# Moving Image 52
# Moving Image 53
# Moving Image 54
# Moving Image 55
# ...

# %%
#sampling from kaggle dataset
import random
KAGGLE_PATH = "archive/chest_xray/train/normal"
TARGET_NORMAL_DIR = "train/normal"

# %%
image_names = os.listdir(KAGGLE_PATH)

# %%
random.shuffle(image_names)

# %%
for i in range(196):
    image_name = image_names[i]
    image_path = os.path.join(KAGGLE_PATH,image_name)
    target_path = os.path.join(TARGET_NORMAL_DIR,image_name)
    shutil.copy2(image_path,target_path)
    print("Copying", i)
# Out:
# Copying 0
# Copying 1
# Copying 2
# Copying 3
# Copying 4
# Copying 5
# Copying 6
# Copying 7
# Copying 8
# Copying 9
# Copying 10
# Copying 11
# Copying 12
# Copying 13
# Copying 14
# Copying 15
# Copying 16
# Copying 17
# Copying 18
# Copying 19
# Copying 20
# Copying 21
# Copying 22
# Copying 23
# Copying 24
# Copying 25
# Copying 26
# Copying 27
# Copying 28
# Copying 29
# Copying 30
# Copying 31
# Copying 32
# Copying 33
# Copying 34
# Copying 35
# Copying 36
# Copying 37
# Copying 38
# Copying 39
# Copying 40
# Copying 41
# Copying 42
# Copying 43
# Copying 44
# Copying 45
# Copying 46
# Copying 47
# Copying 48
# Copying 49
# Copying 50
# Copying 51
# Copying 52
# Copying 53
# Copying 54
# Copying 55
# Copying 56
# Copying 57
# Copying 58
# Copying 59
# Copying 60
# Copying 61
# Copying 62
# Copying 63
# Copying 64
# Copying 65
# Copying 66
# Copying 67
# Copying 68
# Copying 69
# Copying 70
# Copying 71
# Copying 72
# Copying 73
# Copying 74
# Copying 75
# Copying 76
# ...

# %%
VAL_path = "VAL/normal"

for i in range(196,250):
    image_name = image_names[i]
    image_path = os.path.join(KAGGLE_PATH,image_name)
    target_path = os.path.join(VAL_path,image_name)
    shutil.copy2(image_path,target_path)
    print("Copying",i)
# Out:
# Copying 196
# Copying 197
# Copying 198
# Copying 199
# Copying 200
# Copying 201
# Copying 202
# Copying 203
# Copying 204
# Copying 205
# Copying 206
# Copying 207
# Copying 208
# Copying 209
# Copying 210
# Copying 211
# Copying 212
# Copying 213
# Copying 214
# Copying 215
# Copying 216
# Copying 217
# Copying 218
# Copying 219
# Copying 220
# Copying 221
# Copying 222
# Copying 223
# Copying 224
# Copying 225
# Copying 226
# Copying 227
# Copying 228
# Copying 229
# Copying 230
# Copying 231
# Copying 232
# Copying 233
# Copying 234
# Copying 235
# Copying 236
# Copying 237
# Copying 238
# Copying 239
# Copying 240
# Copying 241
# Copying 242
# Copying 243
# Copying 244
# Copying 245
# Copying 246
# Copying 247
# Copying 248
# Copying 249

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras.layers import *
from keras.models import *
from keras.preprocessing import image
from keras.preprocessing import image

# %%
TRAIN_PATH = "train"
VAL_PATH = "VAL"

# %%
# CNN based model in keras

model = Sequential()
model.add(Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(224,224,3)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss=keras.losses.binary_crossentropy,optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 220, 220, 64)      18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 110, 110, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# ...

# %%
#Train from scratch 
train_datagen = image.ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,
) 

test_dataset = image.ImageDataGenerator(rescale=1./255)

# %%
# generating training images in required format
train_generator = train_datagen.flow_from_directory(
    'Train',
    target_size = (224,224),
    batch_size = 32,
    class_mode = 'binary'
)
# Out:
# Found 272 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'COVID': 0, 'normal': 1}

# %%
# generating validating images in required format
val_generator = test_dataset.flow_from_directory(
    'VAL',
    target_size = (224,224),
    batch_size = 32,
    class_mode = 'binary'
)
# Out:
# Found 120 images belonging to 2 classes.

# %%
hist = model.fit(
    train_generator,
    steps_per_epoch=8,
    epochs=10,
    validation_data = val_generator,
    validation_steps=2
)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 69s 9s/step - loss: 2.6965 - accuracy: 0.5388 - val_loss: 0.6855 - val_accuracy: 0.5156
# Epoch 2/10
# 8/8 [==============================] - 43s 5s/step - loss: 0.6629 - accuracy: 0.6121 - val_loss: 0.6339 - val_accuracy: 0.6719
# Epoch 3/10
# 8/8 [==============================] - 43s 5s/step - loss: 0.5780 - accuracy: 0.7363 - val_loss: 0.4130 - val_accuracy: 0.9688
# Epoch 4/10
# 8/8 [==============================] - 43s 5s/step - loss: 0.3782 - accuracy: 0.8280 - val_loss: 0.2170 - val_accuracy: 0.9375
# Epoch 5/10
# 8/8 [==============================] - 43s 5s/step - loss: 0.4533 - accuracy: 0.8162 - val_loss: 0.2300 - val_accuracy: 0.9688
# Epoch 6/10
# 8/8 [==============================] - 47s 6s/step - loss: 0.3729 - accuracy: 0.8527 - val_loss: 0.2174 - val_accuracy: 0.9844
# Epoch 7/10
# 8/8 [==============================] - 54s 7s/step - loss: 0.2415 - accuracy: 0.8916 - val_loss: 0.1110 - val_accuracy: 0.9844
# ...

# %%
model.save('covidModel.h5')

# %%
cv2.imshow('my image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from keras.preprocessing import image
test_image = image.load_img('test123.jpg',target_size=(224,224))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)

# %%
print(model.predict(test_image))
# Out:
# [[0.]]
